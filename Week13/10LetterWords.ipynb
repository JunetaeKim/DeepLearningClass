# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import LSTM, Input, Dense, TimeDistributed, RepeatVector, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import Model
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data load

# %%
Dataset = pd.read_csv('../Dataset/10LetterWords.txt', header=None)

# %%
Dataset
# Out:
#                0
# 0     abbreviate
# 1     abdication
# 2     aberration
# 3     abjuration
# 4     abnegation
# ...          ...
# 2561  wrongdoing
# 2562  xenophobia
# 2563  xerography
# 2564  yesteryear
# 2565  zoological
#
# [2566 rows x 1 columns]

# %% [markdown]
# ### Alphabet table generation

# %%
# define the raw dataset
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
# create mapping of characters to integers (0-25) and the reverse
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))

# one-hot encoding for alphabets
AlphTab = pd.DataFrame(char_to_int,index = [0]).T
AlphOneHot =  pd.get_dummies(AlphTab[0])

# %% [markdown]
# ### Data encoding; alphabet to numeric values

# %%
AlphaEncode = []
for word in Dataset.values:
    SubVec = []
    for char in word[0]:
        CharIDX = char_to_int[char.upper()]
        SubVec.append(AlphOneHot.iloc[CharIDX].values[None])
    SubVec = np.concatenate(SubVec, axis=0)
    AlphaEncode.append(SubVec[None])
AlphaEncode = np.concatenate(AlphaEncode)

# %% [markdown]
# ### Data selection

# %%
### Data selection for input and output 
'''Complete the code below to process the data set
InpData =  # Five input alphabets
TargetData = # Five output alphabets
'''

# %% [markdown]
# ### Model save directory setting

# %%
save_path = './Results/'
if not os.path.exists(save_path):
    os.mkdir(save_path)

# %% [markdown]
# ### Model definition

# %%
def WordsModel ():
"Please complete the code to define your model here"
    return Model(InpL,Output)

# %%
### Model checkpoint
ModelSaveSameName = save_path+'10LetterWordM.hdf5'
ModelSave = ModelCheckpoint(filepath=ModelSaveSameName, monitor='loss', verbose=1, save_best_only=True)

### Model Early stop
EarlyStop = EarlyStopping(monitor='loss', patience=100)

WordsM = WordsModel()
WordsM.compile(loss=tf.losses.categorical_crossentropy, optimizer='adam', metrics =['accuracy'])
WordsMHist = WordsM.fit(InpData, TargetData,  epochs=2000, batch_size=100,  verbose=1, callbacks=[ModelSave, EarlyStop])
# Out:
# Epoch 1/2000
# 26/26 [==============================] - 7s 22ms/step - loss: 3.2300 - accuracy: 0.0993
#
# Epoch 00001: loss improved from inf to 3.18711, saving model to ./Results\10LetterWordM.hdf5
# Epoch 2/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.9059 - accuracy: 0.1587
#
# Epoch 00002: loss improved from 3.18711 to 2.84559, saving model to ./Results\10LetterWordM.hdf5
# Epoch 3/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.7450 - accuracy: 0.2259
#
# Epoch 00003: loss improved from 2.84559 to 2.71667, saving model to ./Results\10LetterWordM.hdf5
# Epoch 4/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.6664 - accuracy: 0.2332
#
# Epoch 00004: loss improved from 2.71667 to 2.65144, saving model to ./Results\10LetterWordM.hdf5
# Epoch 5/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 2.6213 - accuracy: 0.2288
#
# Epoch 00005: loss improved from 2.65144 to 2.60622, saving model to ./Results\10LetterWordM.hdf5
# Epoch 6/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.5815 - accuracy: 0.2425
#
# Epoch 00006: loss improved from 2.60622 to 2.57732, saving model to ./Results\10LetterWordM.hdf5
# Epoch 7/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.5653 - accuracy: 0.2270
#
# Epoch 00007: loss improved from 2.57732 to 2.55516, saving model to ./Results\10LetterWordM.hdf5
# Epoch 8/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.5340 - accuracy: 0.2369
#
# Epoch 00008: loss improved from 2.55516 to 2.53899, saving model to ./Results\10LetterWordM.hdf5
# Epoch 9/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.5121 - accuracy: 0.2346
#
# Epoch 00009: loss improved from 2.53899 to 2.52462, saving model to ./Results\10LetterWordM.hdf5
# Epoch 10/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.5004 - accuracy: 0.2345
#
# Epoch 00010: loss improved from 2.52462 to 2.51060, saving model to ./Results\10LetterWordM.hdf5
# Epoch 11/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.4994 - accuracy: 0.2392
#
# Epoch 00011: loss improved from 2.51060 to 2.50095, saving model to ./Results\10LetterWordM.hdf5
# Epoch 12/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.4851 - accuracy: 0.2371
#
# Epoch 00012: loss improved from 2.50095 to 2.49089, saving model to ./Results\10LetterWordM.hdf5
# Epoch 13/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.4755 - accuracy: 0.2331
#
# Epoch 00013: loss improved from 2.49089 to 2.48423, saving model to ./Results\10LetterWordM.hdf5
# Epoch 14/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.4722 - accuracy: 0.2353
#
# Epoch 00014: loss improved from 2.48423 to 2.47598, saving model to ./Results\10LetterWordM.hdf5
# Epoch 15/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 2.4684 - accuracy: 0.2395 0s - loss: 2.4807 - accu
#
# Epoch 00015: loss improved from 2.47598 to 2.46682, saving model to ./Results\10LetterWordM.hdf5
# Epoch 16/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.4494 - accuracy: 0.2475
#
# Epoch 00016: loss improved from 2.46682 to 2.45450, saving model to ./Results\10LetterWordM.hdf5
# Epoch 17/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.4278 - accuracy: 0.2458
#
# Epoch 00017: loss improved from 2.45450 to 2.44203, saving model to ./Results\10LetterWordM.hdf5
# Epoch 18/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.4224 - accuracy: 0.2712
#
# Epoch 00018: loss improved from 2.44203 to 2.42746, saving model to ./Results\10LetterWordM.hdf5
# Epoch 19/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.4273 - accuracy: 0.2782
#
# Epoch 00019: loss improved from 2.42746 to 2.41381, saving model to ./Results\10LetterWordM.hdf5
# Epoch 20/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.3902 - accuracy: 0.2889
#
# Epoch 00020: loss improved from 2.41381 to 2.40131, saving model to ./Results\10LetterWordM.hdf5
# Epoch 21/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.3857 - accuracy: 0.2912
#
# Epoch 00021: loss improved from 2.40131 to 2.38905, saving model to ./Results\10LetterWordM.hdf5
# Epoch 22/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.3842 - accuracy: 0.2900
#
# Epoch 00022: loss improved from 2.38905 to 2.37471, saving model to ./Results\10LetterWordM.hdf5
# Epoch 23/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.3668 - accuracy: 0.2942
#
# Epoch 00023: loss improved from 2.37471 to 2.36255, saving model to ./Results\10LetterWordM.hdf5
# Epoch 24/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.3581 - accuracy: 0.2993
#
# Epoch 00024: loss improved from 2.36255 to 2.35168, saving model to ./Results\10LetterWordM.hdf5
# Epoch 25/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.3421 - accuracy: 0.2965
#
# Epoch 00025: loss improved from 2.35168 to 2.33744, saving model to ./Results\10LetterWordM.hdf5
# Epoch 26/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.3361 - accuracy: 0.3052
#
# Epoch 00026: loss improved from 2.33744 to 2.32411, saving model to ./Results\10LetterWordM.hdf5
# Epoch 27/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.3278 - accuracy: 0.2912
#
# Epoch 00027: loss improved from 2.32411 to 2.30926, saving model to ./Results\10LetterWordM.hdf5
# Epoch 28/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.2848 - accuracy: 0.3070
#
# Epoch 00028: loss improved from 2.30926 to 2.29334, saving model to ./Results\10LetterWordM.hdf5
# Epoch 29/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.2981 - accuracy: 0.2951
#
# Epoch 00029: loss improved from 2.29334 to 2.27889, saving model to ./Results\10LetterWordM.hdf5
# Epoch 30/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.2725 - accuracy: 0.3010
#
# Epoch 00030: loss improved from 2.27889 to 2.26373, saving model to ./Results\10LetterWordM.hdf5
# Epoch 31/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.2390 - accuracy: 0.3053
#
# Epoch 00031: loss improved from 2.26373 to 2.25083, saving model to ./Results\10LetterWordM.hdf5
# Epoch 32/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.2456 - accuracy: 0.3053
#
# Epoch 00032: loss improved from 2.25083 to 2.24012, saving model to ./Results\10LetterWordM.hdf5
# Epoch 33/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.2180 - accuracy: 0.3189
#
# Epoch 00033: loss improved from 2.24012 to 2.22425, saving model to ./Results\10LetterWordM.hdf5
# Epoch 34/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.1965 - accuracy: 0.3314
#
# Epoch 00034: loss improved from 2.22425 to 2.21336, saving model to ./Results\10LetterWordM.hdf5
# Epoch 35/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.2092 - accuracy: 0.3166
#
# Epoch 00035: loss improved from 2.21336 to 2.20593, saving model to ./Results\10LetterWordM.hdf5
# Epoch 36/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.1917 - accuracy: 0.3193
#
# Epoch 00036: loss improved from 2.20593 to 2.18935, saving model to ./Results\10LetterWordM.hdf5
# Epoch 37/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 2.2031 - accuracy: 0.3194
#
# Epoch 00037: loss improved from 2.18935 to 2.18149, saving model to ./Results\10LetterWordM.hdf5
# Epoch 38/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.1572 - accuracy: 0.3351
#
# Epoch 00038: loss improved from 2.18149 to 2.17134, saving model to ./Results\10LetterWordM.hdf5
# Epoch 39/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.1728 - accuracy: 0.3284
#
# Epoch 00039: loss improved from 2.17134 to 2.16046, saving model to ./Results\10LetterWordM.hdf5
# Epoch 40/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.1447 - accuracy: 0.3423
#
# Epoch 00040: loss improved from 2.16046 to 2.15280, saving model to ./Results\10LetterWordM.hdf5
# Epoch 41/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 2.1516 - accuracy: 0.3414
#
# Epoch 00041: loss improved from 2.15280 to 2.14472, saving model to ./Results\10LetterWordM.hdf5
# Epoch 42/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.1161 - accuracy: 0.3486
#
# Epoch 00042: loss improved from 2.14472 to 2.13683, saving model to ./Results\10LetterWordM.hdf5
# Epoch 43/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.1445 - accuracy: 0.3411
#
# Epoch 00043: loss improved from 2.13683 to 2.12962, saving model to ./Results\10LetterWordM.hdf5
# Epoch 44/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.1557 - accuracy: 0.3254
#
# Epoch 00044: loss improved from 2.12962 to 2.12342, saving model to ./Results\10LetterWordM.hdf5
# Epoch 45/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 2.1089 - accuracy: 0.3370
#
# Epoch 00045: loss improved from 2.12342 to 2.11898, saving model to ./Results\10LetterWordM.hdf5
# Epoch 46/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0957 - accuracy: 0.3412
#
# Epoch 00046: loss improved from 2.11898 to 2.10496, saving model to ./Results\10LetterWordM.hdf5
# Epoch 47/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0804 - accuracy: 0.3542
#
# Epoch 00047: loss improved from 2.10496 to 2.09785, saving model to ./Results\10LetterWordM.hdf5
# Epoch 48/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0795 - accuracy: 0.3478
#
# Epoch 00048: loss improved from 2.09785 to 2.09284, saving model to ./Results\10LetterWordM.hdf5
# Epoch 49/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0630 - accuracy: 0.3538
#
# Epoch 00049: loss improved from 2.09284 to 2.08406, saving model to ./Results\10LetterWordM.hdf5
# Epoch 50/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 2.0637 - accuracy: 0.3565
#
# Epoch 00050: loss improved from 2.08406 to 2.07953, saving model to ./Results\10LetterWordM.hdf5
# Epoch 51/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.0871 - accuracy: 0.3512
#
# Epoch 00051: loss did not improve from 2.07953
# Epoch 52/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.0699 - accuracy: 0.3546
#
# Epoch 00052: loss improved from 2.07953 to 2.07101, saving model to ./Results\10LetterWordM.hdf5
# Epoch 53/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.0571 - accuracy: 0.3655
#
# Epoch 00053: loss improved from 2.07101 to 2.05717, saving model to ./Results\10LetterWordM.hdf5
# Epoch 54/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.0453 - accuracy: 0.3610
#
# Epoch 00054: loss improved from 2.05717 to 2.05191, saving model to ./Results\10LetterWordM.hdf5
# Epoch 55/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.0810 - accuracy: 0.3494
#
# Epoch 00055: loss improved from 2.05191 to 2.04634, saving model to ./Results\10LetterWordM.hdf5
# Epoch 56/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 2.0195 - accuracy: 0.3802
#
# Epoch 00056: loss improved from 2.04634 to 2.04066, saving model to ./Results\10LetterWordM.hdf5
# Epoch 57/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 2.0353 - accuracy: 0.3701
#
# Epoch 00057: loss did not improve from 2.04066
# Epoch 58/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0285 - accuracy: 0.3690
#
# Epoch 00058: loss improved from 2.04066 to 2.02868, saving model to ./Results\10LetterWordM.hdf5
# Epoch 59/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 2.0224 - accuracy: 0.3759
#
# Epoch 00059: loss improved from 2.02868 to 2.02731, saving model to ./Results\10LetterWordM.hdf5
# Epoch 60/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 2.0248 - accuracy: 0.3732
#
# Epoch 00060: loss improved from 2.02731 to 2.02461, saving model to ./Results\10LetterWordM.hdf5
# Epoch 61/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.9997 - accuracy: 0.3768
#
# Epoch 00061: loss improved from 2.02461 to 2.01877, saving model to ./Results\10LetterWordM.hdf5
# Epoch 62/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0290 - accuracy: 0.3627
#
# Epoch 00062: loss improved from 2.01877 to 2.00922, saving model to ./Results\10LetterWordM.hdf5
# Epoch 63/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.9977 - accuracy: 0.3849
#
# Epoch 00063: loss improved from 2.00922 to 2.00211, saving model to ./Results\10LetterWordM.hdf5
# Epoch 64/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0025 - accuracy: 0.3816
#
# Epoch 00064: loss improved from 2.00211 to 1.99641, saving model to ./Results\10LetterWordM.hdf5
# Epoch 65/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9854 - accuracy: 0.3827
#
# Epoch 00065: loss improved from 1.99641 to 1.98864, saving model to ./Results\10LetterWordM.hdf5
# Epoch 66/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9894 - accuracy: 0.3780
#
# Epoch 00066: loss improved from 1.98864 to 1.98657, saving model to ./Results\10LetterWordM.hdf5
# Epoch 67/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9763 - accuracy: 0.3852
#
# Epoch 00067: loss improved from 1.98657 to 1.97666, saving model to ./Results\10LetterWordM.hdf5
# Epoch 68/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9689 - accuracy: 0.3881
#
# Epoch 00068: loss improved from 1.97666 to 1.97263, saving model to ./Results\10LetterWordM.hdf5
# Epoch 69/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9717 - accuracy: 0.3883
#
# Epoch 00069: loss improved from 1.97263 to 1.96926, saving model to ./Results\10LetterWordM.hdf5
# Epoch 70/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9732 - accuracy: 0.3896
#
# Epoch 00070: loss did not improve from 1.96926
# Epoch 71/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.9536 - accuracy: 0.3908
#
# Epoch 00071: loss improved from 1.96926 to 1.95672, saving model to ./Results\10LetterWordM.hdf5
# Epoch 72/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9446 - accuracy: 0.3948
#
# Epoch 00072: loss improved from 1.95672 to 1.95502, saving model to ./Results\10LetterWordM.hdf5
# Epoch 73/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9181 - accuracy: 0.4123
#
# Epoch 00073: loss improved from 1.95502 to 1.95119, saving model to ./Results\10LetterWordM.hdf5
# Epoch 74/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9267 - accuracy: 0.4044
#
# Epoch 00074: loss improved from 1.95119 to 1.94897, saving model to ./Results\10LetterWordM.hdf5
# Epoch 75/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9523 - accuracy: 0.3978
#
# Epoch 00075: loss improved from 1.94897 to 1.93945, saving model to ./Results\10LetterWordM.hdf5
# Epoch 76/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9311 - accuracy: 0.4038
#
# Epoch 00076: loss improved from 1.93945 to 1.93445, saving model to ./Results\10LetterWordM.hdf5
# Epoch 77/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9230 - accuracy: 0.4059
#
# Epoch 00077: loss improved from 1.93445 to 1.92882, saving model to ./Results\10LetterWordM.hdf5
# Epoch 78/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9188 - accuracy: 0.4080
#
# Epoch 00078: loss improved from 1.92882 to 1.92167, saving model to ./Results\10LetterWordM.hdf5
# Epoch 79/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9133 - accuracy: 0.4153
#
# Epoch 00079: loss improved from 1.92167 to 1.91574, saving model to ./Results\10LetterWordM.hdf5
# Epoch 80/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.9156 - accuracy: 0.4186
#
# Epoch 00080: loss did not improve from 1.91574
# Epoch 81/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.8998 - accuracy: 0.4222
#
# Epoch 00081: loss improved from 1.91574 to 1.90792, saving model to ./Results\10LetterWordM.hdf5
# Epoch 82/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.9003 - accuracy: 0.4147
#
# Epoch 00082: loss improved from 1.90792 to 1.90226, saving model to ./Results\10LetterWordM.hdf5
# Epoch 83/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.8826 - accuracy: 0.4216
#
# Epoch 00083: loss improved from 1.90226 to 1.89724, saving model to ./Results\10LetterWordM.hdf5
# Epoch 84/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8754 - accuracy: 0.4352
#
# Epoch 00084: loss improved from 1.89724 to 1.89337, saving model to ./Results\10LetterWordM.hdf5
# Epoch 85/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.8994 - accuracy: 0.4247
#
# Epoch 00085: loss improved from 1.89337 to 1.89131, saving model to ./Results\10LetterWordM.hdf5
# Epoch 86/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.8809 - accuracy: 0.4282
#
# Epoch 00086: loss improved from 1.89131 to 1.88146, saving model to ./Results\10LetterWordM.hdf5
# Epoch 87/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8889 - accuracy: 0.4253
#
# Epoch 00087: loss improved from 1.88146 to 1.87831, saving model to ./Results\10LetterWordM.hdf5
# Epoch 88/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8709 - accuracy: 0.4324
#
# Epoch 00088: loss improved from 1.87831 to 1.87116, saving model to ./Results\10LetterWordM.hdf5
# Epoch 89/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8870 - accuracy: 0.4233
#
# Epoch 00089: loss improved from 1.87116 to 1.86436, saving model to ./Results\10LetterWordM.hdf5
# Epoch 90/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8662 - accuracy: 0.4346
#
# Epoch 00090: loss improved from 1.86436 to 1.85702, saving model to ./Results\10LetterWordM.hdf5
# Epoch 91/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8671 - accuracy: 0.4268
#
# Epoch 00091: loss did not improve from 1.85702
# Epoch 92/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8304 - accuracy: 0.4424
#
# Epoch 00092: loss improved from 1.85702 to 1.85446, saving model to ./Results\10LetterWordM.hdf5
# Epoch 93/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.8493 - accuracy: 0.4391
#
# Epoch 00093: loss improved from 1.85446 to 1.84566, saving model to ./Results\10LetterWordM.hdf5
# Epoch 94/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8599 - accuracy: 0.4422
#
# Epoch 00094: loss improved from 1.84566 to 1.83642, saving model to ./Results\10LetterWordM.hdf5
# Epoch 95/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8284 - accuracy: 0.4495
#
# Epoch 00095: loss improved from 1.83642 to 1.83149, saving model to ./Results\10LetterWordM.hdf5
# Epoch 96/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8156 - accuracy: 0.4539
#
# Epoch 00096: loss improved from 1.83149 to 1.82828, saving model to ./Results\10LetterWordM.hdf5
# Epoch 97/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.8270 - accuracy: 0.4502
#
# Epoch 00097: loss improved from 1.82828 to 1.82666, saving model to ./Results\10LetterWordM.hdf5
# Epoch 98/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7829 - accuracy: 0.4584
#
# Epoch 00098: loss improved from 1.82666 to 1.82288, saving model to ./Results\10LetterWordM.hdf5
# Epoch 99/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.7998 - accuracy: 0.4581
#
# Epoch 00099: loss improved from 1.82288 to 1.81440, saving model to ./Results\10LetterWordM.hdf5
# Epoch 100/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8045 - accuracy: 0.4497
#
# Epoch 00100: loss did not improve from 1.81440
# Epoch 101/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.7743 - accuracy: 0.4642
#
# Epoch 00101: loss improved from 1.81440 to 1.80564, saving model to ./Results\10LetterWordM.hdf5
# Epoch 102/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8009 - accuracy: 0.4539
#
# Epoch 00102: loss improved from 1.80564 to 1.80397, saving model to ./Results\10LetterWordM.hdf5
# Epoch 103/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.8160 - accuracy: 0.4591
#
# Epoch 00103: loss improved from 1.80397 to 1.80046, saving model to ./Results\10LetterWordM.hdf5
# Epoch 104/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7665 - accuracy: 0.4718
#
# Epoch 00104: loss improved from 1.80046 to 1.79090, saving model to ./Results\10LetterWordM.hdf5
# Epoch 105/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7904 - accuracy: 0.4650
#
# Epoch 00105: loss improved from 1.79090 to 1.78505, saving model to ./Results\10LetterWordM.hdf5
# Epoch 106/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.7570 - accuracy: 0.4686
#
# Epoch 00106: loss improved from 1.78505 to 1.78117, saving model to ./Results\10LetterWordM.hdf5
# Epoch 107/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7503 - accuracy: 0.4694
#
# Epoch 00107: loss improved from 1.78117 to 1.77089, saving model to ./Results\10LetterWordM.hdf5
# Epoch 108/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7397 - accuracy: 0.4749
#
# Epoch 00108: loss did not improve from 1.77089
# Epoch 109/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7596 - accuracy: 0.4688
#
# Epoch 00109: loss improved from 1.77089 to 1.76515, saving model to ./Results\10LetterWordM.hdf5
# Epoch 110/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7945 - accuracy: 0.4647
#
# Epoch 00110: loss improved from 1.76515 to 1.76210, saving model to ./Results\10LetterWordM.hdf5
# Epoch 111/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7526 - accuracy: 0.4741
#
# Epoch 00111: loss improved from 1.76210 to 1.75812, saving model to ./Results\10LetterWordM.hdf5
# Epoch 112/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.7494 - accuracy: 0.4717
#
# Epoch 00112: loss improved from 1.75812 to 1.75628, saving model to ./Results\10LetterWordM.hdf5
# Epoch 113/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.7419 - accuracy: 0.4739
#
# Epoch 00113: loss improved from 1.75628 to 1.74462, saving model to ./Results\10LetterWordM.hdf5
# Epoch 114/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.7407 - accuracy: 0.4714
#
# Epoch 00114: loss improved from 1.74462 to 1.73817, saving model to ./Results\10LetterWordM.hdf5
# Epoch 115/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.7324 - accuracy: 0.4761
#
# Epoch 00115: loss improved from 1.73817 to 1.73332, saving model to ./Results\10LetterWordM.hdf5
# Epoch 116/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.6918 - accuracy: 0.4865
#
# Epoch 00116: loss improved from 1.73332 to 1.72920, saving model to ./Results\10LetterWordM.hdf5
# Epoch 117/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7386 - accuracy: 0.4815
#
# Epoch 00117: loss improved from 1.72920 to 1.72768, saving model to ./Results\10LetterWordM.hdf5
# Epoch 118/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.7170 - accuracy: 0.4838
#
# Epoch 00118: loss improved from 1.72768 to 1.72435, saving model to ./Results\10LetterWordM.hdf5
# Epoch 119/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.7163 - accuracy: 0.4820
#
# Epoch 00119: loss did not improve from 1.72435
# Epoch 120/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.7011 - accuracy: 0.4838
#
# Epoch 00120: loss improved from 1.72435 to 1.71878, saving model to ./Results\10LetterWordM.hdf5
# Epoch 121/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7059 - accuracy: 0.4887
#
# Epoch 00121: loss improved from 1.71878 to 1.71305, saving model to ./Results\10LetterWordM.hdf5
# Epoch 122/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7180 - accuracy: 0.4799
#
# Epoch 00122: loss improved from 1.71305 to 1.70217, saving model to ./Results\10LetterWordM.hdf5
# Epoch 123/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.6957 - accuracy: 0.4846
#
# Epoch 00123: loss improved from 1.70217 to 1.69882, saving model to ./Results\10LetterWordM.hdf5
# Epoch 124/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.6720 - accuracy: 0.5039 0s - loss: 1.6538 - accura
#
# Epoch 00124: loss improved from 1.69882 to 1.69185, saving model to ./Results\10LetterWordM.hdf5
# Epoch 125/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6964 - accuracy: 0.4912
#
# Epoch 00125: loss improved from 1.69185 to 1.68748, saving model to ./Results\10LetterWordM.hdf5
# Epoch 126/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 1.6814 - accuracy: 0.4944
#
# Epoch 00126: loss improved from 1.68748 to 1.68250, saving model to ./Results\10LetterWordM.hdf5
# Epoch 127/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.6754 - accuracy: 0.4948
#
# Epoch 00127: loss improved from 1.68250 to 1.67810, saving model to ./Results\10LetterWordM.hdf5
# Epoch 128/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.7051 - accuracy: 0.4928
#
# Epoch 00128: loss improved from 1.67810 to 1.67285, saving model to ./Results\10LetterWordM.hdf5
# Epoch 129/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6685 - accuracy: 0.4887
#
# Epoch 00129: loss improved from 1.67285 to 1.66756, saving model to ./Results\10LetterWordM.hdf5
# Epoch 130/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6668 - accuracy: 0.4965
#
# Epoch 00130: loss improved from 1.66756 to 1.66291, saving model to ./Results\10LetterWordM.hdf5
# Epoch 131/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.6610 - accuracy: 0.4974
#
# Epoch 00131: loss improved from 1.66291 to 1.66183, saving model to ./Results\10LetterWordM.hdf5
# Epoch 132/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6484 - accuracy: 0.5071
#
# Epoch 00132: loss improved from 1.66183 to 1.65994, saving model to ./Results\10LetterWordM.hdf5
# Epoch 133/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6580 - accuracy: 0.4993
#
# Epoch 00133: loss improved from 1.65994 to 1.65207, saving model to ./Results\10LetterWordM.hdf5
# Epoch 134/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6340 - accuracy: 0.5157
#
# Epoch 00134: loss improved from 1.65207 to 1.64501, saving model to ./Results\10LetterWordM.hdf5
# Epoch 135/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6660 - accuracy: 0.4978
#
# Epoch 00135: loss improved from 1.64501 to 1.64115, saving model to ./Results\10LetterWordM.hdf5
# Epoch 136/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6329 - accuracy: 0.5086
#
# Epoch 00136: loss improved from 1.64115 to 1.63695, saving model to ./Results\10LetterWordM.hdf5
# Epoch 137/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5855 - accuracy: 0.5358
#
# Epoch 00137: loss improved from 1.63695 to 1.62979, saving model to ./Results\10LetterWordM.hdf5
# Epoch 138/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.6496 - accuracy: 0.5116
#
# Epoch 00138: loss improved from 1.62979 to 1.62911, saving model to ./Results\10LetterWordM.hdf5
# Epoch 139/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.6179 - accuracy: 0.5134
#
# Epoch 00139: loss improved from 1.62911 to 1.62351, saving model to ./Results\10LetterWordM.hdf5
# Epoch 140/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5986 - accuracy: 0.5204
#
# Epoch 00140: loss improved from 1.62351 to 1.61413, saving model to ./Results\10LetterWordM.hdf5
# Epoch 141/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.6259 - accuracy: 0.5093
#
# Epoch 00141: loss improved from 1.61413 to 1.61311, saving model to ./Results\10LetterWordM.hdf5
# Epoch 142/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5924 - accuracy: 0.5231
#
# Epoch 00142: loss did not improve from 1.61311
# Epoch 143/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.6081 - accuracy: 0.5149
#
# Epoch 00143: loss improved from 1.61311 to 1.59968, saving model to ./Results\10LetterWordM.hdf5
# Epoch 144/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5938 - accuracy: 0.5269
#
# Epoch 00144: loss improved from 1.59968 to 1.59486, saving model to ./Results\10LetterWordM.hdf5
# Epoch 145/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5894 - accuracy: 0.5286
#
# Epoch 00145: loss improved from 1.59486 to 1.59315, saving model to ./Results\10LetterWordM.hdf5
# Epoch 146/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5713 - accuracy: 0.5291
#
# Epoch 00146: loss improved from 1.59315 to 1.58517, saving model to ./Results\10LetterWordM.hdf5
# Epoch 147/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5634 - accuracy: 0.5360
#
# Epoch 00147: loss improved from 1.58517 to 1.58281, saving model to ./Results\10LetterWordM.hdf5
# Epoch 148/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5907 - accuracy: 0.5274
#
# Epoch 00148: loss improved from 1.58281 to 1.57667, saving model to ./Results\10LetterWordM.hdf5
# Epoch 149/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5600 - accuracy: 0.5343
#
# Epoch 00149: loss improved from 1.57667 to 1.57227, saving model to ./Results\10LetterWordM.hdf5
# Epoch 150/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5730 - accuracy: 0.5299
#
# Epoch 00150: loss improved from 1.57227 to 1.57151, saving model to ./Results\10LetterWordM.hdf5
# Epoch 151/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5719 - accuracy: 0.5260
#
# Epoch 00151: loss did not improve from 1.57151
# Epoch 152/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.5524 - accuracy: 0.5332
#
# Epoch 00152: loss improved from 1.57151 to 1.56975, saving model to ./Results\10LetterWordM.hdf5
# Epoch 153/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.5624 - accuracy: 0.5342
#
# Epoch 00153: loss improved from 1.56975 to 1.56214, saving model to ./Results\10LetterWordM.hdf5
# Epoch 154/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.5395 - accuracy: 0.5399
#
# Epoch 00154: loss improved from 1.56214 to 1.55502, saving model to ./Results\10LetterWordM.hdf5
# Epoch 155/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5722 - accuracy: 0.5232
#
# Epoch 00155: loss improved from 1.55502 to 1.55006, saving model to ./Results\10LetterWordM.hdf5
# Epoch 156/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5511 - accuracy: 0.5306
#
# Epoch 00156: loss improved from 1.55006 to 1.54421, saving model to ./Results\10LetterWordM.hdf5
# Epoch 157/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.5036 - accuracy: 0.5458
#
# Epoch 00157: loss improved from 1.54421 to 1.53579, saving model to ./Results\10LetterWordM.hdf5
# Epoch 158/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5014 - accuracy: 0.5495
#
# Epoch 00158: loss improved from 1.53579 to 1.53370, saving model to ./Results\10LetterWordM.hdf5
# Epoch 159/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5053 - accuracy: 0.5534
#
# Epoch 00159: loss improved from 1.53370 to 1.53147, saving model to ./Results\10LetterWordM.hdf5
# Epoch 160/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5055 - accuracy: 0.5472
#
# Epoch 00160: loss improved from 1.53147 to 1.52591, saving model to ./Results\10LetterWordM.hdf5
# Epoch 161/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.5305 - accuracy: 0.5445
#
# Epoch 00161: loss improved from 1.52591 to 1.52057, saving model to ./Results\10LetterWordM.hdf5
# Epoch 162/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.5075 - accuracy: 0.5530
#
# Epoch 00162: loss improved from 1.52057 to 1.51615, saving model to ./Results\10LetterWordM.hdf5
# Epoch 163/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5135 - accuracy: 0.5406
#
# Epoch 00163: loss did not improve from 1.51615
# Epoch 164/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.4854 - accuracy: 0.5560
#
# Epoch 00164: loss improved from 1.51615 to 1.51058, saving model to ./Results\10LetterWordM.hdf5
# Epoch 165/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5038 - accuracy: 0.5470
#
# Epoch 00165: loss improved from 1.51058 to 1.50418, saving model to ./Results\10LetterWordM.hdf5
# Epoch 166/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5045 - accuracy: 0.5561
#
# Epoch 00166: loss improved from 1.50418 to 1.50316, saving model to ./Results\10LetterWordM.hdf5
# Epoch 167/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5091 - accuracy: 0.5473
#
# Epoch 00167: loss improved from 1.50316 to 1.50251, saving model to ./Results\10LetterWordM.hdf5
# Epoch 168/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4720 - accuracy: 0.5637
#
# Epoch 00168: loss improved from 1.50251 to 1.49409, saving model to ./Results\10LetterWordM.hdf5
# Epoch 169/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5119 - accuracy: 0.5442
#
# Epoch 00169: loss improved from 1.49409 to 1.48845, saving model to ./Results\10LetterWordM.hdf5
# Epoch 170/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4870 - accuracy: 0.5531
#
# Epoch 00170: loss improved from 1.48845 to 1.48368, saving model to ./Results\10LetterWordM.hdf5
# Epoch 171/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4982 - accuracy: 0.5506
#
# Epoch 00171: loss improved from 1.48368 to 1.48313, saving model to ./Results\10LetterWordM.hdf5
# Epoch 172/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.5025 - accuracy: 0.5444
#
# Epoch 00172: loss did not improve from 1.48313
# Epoch 173/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.4605 - accuracy: 0.5619
#
# Epoch 00173: loss improved from 1.48313 to 1.46967, saving model to ./Results\10LetterWordM.hdf5
# Epoch 174/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4477 - accuracy: 0.5659 0s - loss: 1.4389 - accuracy:
#
# Epoch 00174: loss improved from 1.46967 to 1.46921, saving model to ./Results\10LetterWordM.hdf5
# Epoch 175/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4569 - accuracy: 0.5588
#
# Epoch 00175: loss improved from 1.46921 to 1.46787, saving model to ./Results\10LetterWordM.hdf5
# Epoch 176/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.4619 - accuracy: 0.5627
#
# Epoch 00176: loss improved from 1.46787 to 1.45891, saving model to ./Results\10LetterWordM.hdf5
# Epoch 177/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4404 - accuracy: 0.5650
#
# Epoch 00177: loss improved from 1.45891 to 1.45327, saving model to ./Results\10LetterWordM.hdf5
# Epoch 178/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4292 - accuracy: 0.5708
#
# Epoch 00178: loss improved from 1.45327 to 1.45216, saving model to ./Results\10LetterWordM.hdf5
# Epoch 179/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4539 - accuracy: 0.5591
#
# Epoch 00179: loss improved from 1.45216 to 1.45081, saving model to ./Results\10LetterWordM.hdf5
# Epoch 180/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4489 - accuracy: 0.5623
#
# Epoch 00180: loss improved from 1.45081 to 1.44858, saving model to ./Results\10LetterWordM.hdf5
# Epoch 181/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.4448 - accuracy: 0.5604
#
# Epoch 00181: loss improved from 1.44858 to 1.44517, saving model to ./Results\10LetterWordM.hdf5
# Epoch 182/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3767 - accuracy: 0.5879
#
# Epoch 00182: loss improved from 1.44517 to 1.43993, saving model to ./Results\10LetterWordM.hdf5
# Epoch 183/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4323 - accuracy: 0.5731
#
# Epoch 00183: loss improved from 1.43993 to 1.43333, saving model to ./Results\10LetterWordM.hdf5
# Epoch 184/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4315 - accuracy: 0.5649
#
# Epoch 00184: loss improved from 1.43333 to 1.42731, saving model to ./Results\10LetterWordM.hdf5
# Epoch 185/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.4465 - accuracy: 0.5658
#
# Epoch 00185: loss did not improve from 1.42731
# Epoch 186/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3942 - accuracy: 0.5864
#
# Epoch 00186: loss improved from 1.42731 to 1.42246, saving model to ./Results\10LetterWordM.hdf5
# Epoch 187/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4194 - accuracy: 0.5652
#
# Epoch 00187: loss improved from 1.42246 to 1.41716, saving model to ./Results\10LetterWordM.hdf5
# Epoch 188/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3986 - accuracy: 0.5859
#
# Epoch 00188: loss improved from 1.41716 to 1.40961, saving model to ./Results\10LetterWordM.hdf5
# Epoch 189/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3927 - accuracy: 0.5815
#
# Epoch 00189: loss improved from 1.40961 to 1.40781, saving model to ./Results\10LetterWordM.hdf5
# Epoch 190/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.3694 - accuracy: 0.5931
#
# Epoch 00190: loss did not improve from 1.40781
# Epoch 191/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4101 - accuracy: 0.5766
#
# Epoch 00191: loss improved from 1.40781 to 1.40677, saving model to ./Results\10LetterWordM.hdf5
# Epoch 192/2000
# 26/26 [==============================] - 1s 22ms/step - loss: 1.3935 - accuracy: 0.5819
#
# Epoch 00192: loss improved from 1.40677 to 1.39535, saving model to ./Results\10LetterWordM.hdf5
# Epoch 193/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.4062 - accuracy: 0.5838
#
# Epoch 00193: loss improved from 1.39535 to 1.38939, saving model to ./Results\10LetterWordM.hdf5
# Epoch 194/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3960 - accuracy: 0.5821
#
# Epoch 00194: loss did not improve from 1.38939
# Epoch 195/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3688 - accuracy: 0.5925
#
# Epoch 00195: loss improved from 1.38939 to 1.38764, saving model to ./Results\10LetterWordM.hdf5
# Epoch 196/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3727 - accuracy: 0.5934
#
# Epoch 00196: loss did not improve from 1.38764
# Epoch 197/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3914 - accuracy: 0.5915
#
# Epoch 00197: loss improved from 1.38764 to 1.37933, saving model to ./Results\10LetterWordM.hdf5
# Epoch 198/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3689 - accuracy: 0.5954
#
# Epoch 00198: loss improved from 1.37933 to 1.37148, saving model to ./Results\10LetterWordM.hdf5
# Epoch 199/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3676 - accuracy: 0.5938
#
# Epoch 00199: loss improved from 1.37148 to 1.36969, saving model to ./Results\10LetterWordM.hdf5
# Epoch 200/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3713 - accuracy: 0.5862
#
# Epoch 00200: loss improved from 1.36969 to 1.36864, saving model to ./Results\10LetterWordM.hdf5
# Epoch 201/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3636 - accuracy: 0.5925
#
# Epoch 00201: loss did not improve from 1.36864
# Epoch 202/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3458 - accuracy: 0.6026
#
# Epoch 00202: loss improved from 1.36864 to 1.36043, saving model to ./Results\10LetterWordM.hdf5
# Epoch 203/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3901 - accuracy: 0.5811
#
# Epoch 00203: loss improved from 1.36043 to 1.35933, saving model to ./Results\10LetterWordM.hdf5
# Epoch 204/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3231 - accuracy: 0.6039
#
# Epoch 00204: loss improved from 1.35933 to 1.35182, saving model to ./Results\10LetterWordM.hdf5
# Epoch 205/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3519 - accuracy: 0.5958
#
# Epoch 00205: loss improved from 1.35182 to 1.34783, saving model to ./Results\10LetterWordM.hdf5
# Epoch 206/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3612 - accuracy: 0.5961
#
# Epoch 00206: loss improved from 1.34783 to 1.34512, saving model to ./Results\10LetterWordM.hdf5
# Epoch 207/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3406 - accuracy: 0.6017
#
# Epoch 00207: loss improved from 1.34512 to 1.34354, saving model to ./Results\10LetterWordM.hdf5
# Epoch 208/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3400 - accuracy: 0.6015
#
# Epoch 00208: loss improved from 1.34354 to 1.33654, saving model to ./Results\10LetterWordM.hdf5
# Epoch 209/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3127 - accuracy: 0.6106
#
# Epoch 00209: loss improved from 1.33654 to 1.33230, saving model to ./Results\10LetterWordM.hdf5
# Epoch 210/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3050 - accuracy: 0.6185
#
# Epoch 00210: loss improved from 1.33230 to 1.32822, saving model to ./Results\10LetterWordM.hdf5
# Epoch 211/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3196 - accuracy: 0.6024
#
# Epoch 00211: loss did not improve from 1.32822
# Epoch 212/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 1.3110 - accuracy: 0.6111
#
# Epoch 00212: loss improved from 1.32822 to 1.32408, saving model to ./Results\10LetterWordM.hdf5
# Epoch 213/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2928 - accuracy: 0.6115
#
# Epoch 00213: loss did not improve from 1.32408
# Epoch 214/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3484 - accuracy: 0.6016
#
# Epoch 00214: loss improved from 1.32408 to 1.31677, saving model to ./Results\10LetterWordM.hdf5
# Epoch 215/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 1.3159 - accuracy: 0.6123
#
# Epoch 00215: loss improved from 1.31677 to 1.31446, saving model to ./Results\10LetterWordM.hdf5
# Epoch 216/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3379 - accuracy: 0.6053
#
# Epoch 00216: loss did not improve from 1.31446
# Epoch 217/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3207 - accuracy: 0.6020
#
# Epoch 00217: loss improved from 1.31446 to 1.31441, saving model to ./Results\10LetterWordM.hdf5
# Epoch 218/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3011 - accuracy: 0.6075
#
# Epoch 00218: loss improved from 1.31441 to 1.30455, saving model to ./Results\10LetterWordM.hdf5
# Epoch 219/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.3043 - accuracy: 0.6144
#
# Epoch 00219: loss improved from 1.30455 to 1.29672, saving model to ./Results\10LetterWordM.hdf5
# Epoch 220/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2917 - accuracy: 0.6146
#
# Epoch 00220: loss did not improve from 1.29672
# Epoch 221/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2868 - accuracy: 0.6138
#
# Epoch 00221: loss did not improve from 1.29672
# Epoch 222/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.3100 - accuracy: 0.6107
#
# Epoch 00222: loss improved from 1.29672 to 1.29221, saving model to ./Results\10LetterWordM.hdf5
# Epoch 223/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2644 - accuracy: 0.6277
#
# Epoch 00223: loss improved from 1.29221 to 1.28795, saving model to ./Results\10LetterWordM.hdf5
# Epoch 224/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2898 - accuracy: 0.6199
#
# Epoch 00224: loss improved from 1.28795 to 1.28577, saving model to ./Results\10LetterWordM.hdf5
# Epoch 225/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2877 - accuracy: 0.6174
#
# Epoch 00225: loss improved from 1.28577 to 1.27552, saving model to ./Results\10LetterWordM.hdf5
# Epoch 226/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2622 - accuracy: 0.6229
#
# Epoch 00226: loss improved from 1.27552 to 1.27213, saving model to ./Results\10LetterWordM.hdf5
# Epoch 227/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2761 - accuracy: 0.6198
#
# Epoch 00227: loss improved from 1.27213 to 1.26951, saving model to ./Results\10LetterWordM.hdf5
# Epoch 228/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2481 - accuracy: 0.6249
#
# Epoch 00228: loss improved from 1.26951 to 1.26087, saving model to ./Results\10LetterWordM.hdf5
# Epoch 229/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2632 - accuracy: 0.6235
#
# Epoch 00229: loss did not improve from 1.26087
# Epoch 230/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2720 - accuracy: 0.6221
#
# Epoch 00230: loss did not improve from 1.26087
# Epoch 231/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 1.2501 - accuracy: 0.6300
#
# Epoch 00231: loss improved from 1.26087 to 1.26010, saving model to ./Results\10LetterWordM.hdf5
# Epoch 232/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 1.2638 - accuracy: 0.6243
#
# Epoch 00232: loss improved from 1.26010 to 1.25449, saving model to ./Results\10LetterWordM.hdf5
# Epoch 233/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2752 - accuracy: 0.6250
#
# Epoch 00233: loss did not improve from 1.25449
# Epoch 234/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 1.2101 - accuracy: 0.6387
#
# Epoch 00234: loss improved from 1.25449 to 1.24311, saving model to ./Results\10LetterWordM.hdf5
# Epoch 235/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2474 - accuracy: 0.6307
#
# Epoch 00235: loss did not improve from 1.24311
# Epoch 236/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2243 - accuracy: 0.6290
#
# Epoch 00236: loss improved from 1.24311 to 1.23633, saving model to ./Results\10LetterWordM.hdf5
# Epoch 237/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2267 - accuracy: 0.6352
#
# Epoch 00237: loss did not improve from 1.23633
# Epoch 238/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.2036 - accuracy: 0.6397
#
# Epoch 00238: loss improved from 1.23633 to 1.23221, saving model to ./Results\10LetterWordM.hdf5
# Epoch 239/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2298 - accuracy: 0.6285
#
# Epoch 00239: loss improved from 1.23221 to 1.22970, saving model to ./Results\10LetterWordM.hdf5
# Epoch 240/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.1947 - accuracy: 0.6400
#
# Epoch 00240: loss improved from 1.22970 to 1.22396, saving model to ./Results\10LetterWordM.hdf5
# Epoch 241/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.1842 - accuracy: 0.6445
#
# Epoch 00241: loss improved from 1.22396 to 1.22086, saving model to ./Results\10LetterWordM.hdf5
# Epoch 242/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2290 - accuracy: 0.6279
#
# Epoch 00242: loss improved from 1.22086 to 1.21913, saving model to ./Results\10LetterWordM.hdf5
# Epoch 243/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2197 - accuracy: 0.6304
#
# Epoch 00243: loss did not improve from 1.21913
# Epoch 244/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 1.1806 - accuracy: 0.6475
#
# Epoch 00244: loss improved from 1.21913 to 1.21897, saving model to ./Results\10LetterWordM.hdf5
# Epoch 245/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.1954 - accuracy: 0.6488
#
# Epoch 00245: loss improved from 1.21897 to 1.21257, saving model to ./Results\10LetterWordM.hdf5
# Epoch 246/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 1.2079 - accuracy: 0.6381
#
# ...
#
# Epoch 01898: loss did not improve from 0.14367
# Epoch 1899/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 0.1371 - accuracy: 0.9320
#
# Epoch 01899: loss did not improve from 0.14367
# Epoch 1900/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1451 - accuracy: 0.9223
#
# Epoch 01900: loss did not improve from 0.14367
# Epoch 1901/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1397 - accuracy: 0.9307
#
# Epoch 01901: loss did not improve from 0.14367
# Epoch 1902/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1402 - accuracy: 0.9335
#
# Epoch 01902: loss did not improve from 0.14367
# Epoch 1903/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1436 - accuracy: 0.9234
#
# Epoch 01903: loss did not improve from 0.14367
# Epoch 1904/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1409 - accuracy: 0.9284
#
# Epoch 01904: loss did not improve from 0.14367
# Epoch 1905/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1396 - accuracy: 0.9282
#
# Epoch 01905: loss did not improve from 0.14367
# Epoch 1906/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 0.1430 - accuracy: 0.9272
#
# Epoch 01906: loss did not improve from 0.14367
# Epoch 1907/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1541 - accuracy: 0.9236
#
# Epoch 01907: loss did not improve from 0.14367
# Epoch 1908/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2671 - accuracy: 0.8981
#
# Epoch 01908: loss did not improve from 0.14367
# Epoch 1909/2000
# 26/26 [==============================] - 0s 18ms/step - loss: 0.4110 - accuracy: 0.8629
#
# Epoch 01909: loss did not improve from 0.14367
# Epoch 1910/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.4167 - accuracy: 0.8592
#
# Epoch 01910: loss did not improve from 0.14367
# Epoch 1911/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.3474 - accuracy: 0.8757
#
# Epoch 01911: loss did not improve from 0.14367
# Epoch 1912/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2902 - accuracy: 0.8913
#
# Epoch 01912: loss did not improve from 0.14367
# Epoch 1913/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2536 - accuracy: 0.8989
#
# Epoch 01913: loss did not improve from 0.14367
# Epoch 1914/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2036 - accuracy: 0.9164
#
# Epoch 01914: loss did not improve from 0.14367
# Epoch 1915/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1621 - accuracy: 0.9264
#
# Epoch 01915: loss did not improve from 0.14367
# Epoch 1916/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 0.1641 - accuracy: 0.9303
#
# Epoch 01916: loss did not improve from 0.14367
# Epoch 1917/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1442 - accuracy: 0.9315
#
# Epoch 01917: loss did not improve from 0.14367
# Epoch 1918/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1459 - accuracy: 0.9311
#
# Epoch 01918: loss did not improve from 0.14367
# Epoch 1919/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1445 - accuracy: 0.9290
#
# Epoch 01919: loss did not improve from 0.14367
# Epoch 1920/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1424 - accuracy: 0.9297
#
# Epoch 01920: loss did not improve from 0.14367
# Epoch 1921/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1450 - accuracy: 0.9277
#
# Epoch 01921: loss did not improve from 0.14367
# Epoch 1922/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1368 - accuracy: 0.9329
#
# Epoch 01922: loss improved from 0.14367 to 0.14308, saving model to ./Results\10LetterWordM.hdf5
# Epoch 1923/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 0.1363 - accuracy: 0.9340
#
# Epoch 01923: loss did not improve from 0.14308
# Epoch 1924/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1442 - accuracy: 0.9242
#
# Epoch 01924: loss did not improve from 0.14308
# Epoch 1925/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1370 - accuracy: 0.9288
#
# Epoch 01925: loss improved from 0.14308 to 0.14294, saving model to ./Results\10LetterWordM.hdf5
# Epoch 1926/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1400 - accuracy: 0.9306
#
# Epoch 01926: loss improved from 0.14294 to 0.14269, saving model to ./Results\10LetterWordM.hdf5
# Epoch 1927/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1370 - accuracy: 0.9329
#
# Epoch 01927: loss did not improve from 0.14269
# Epoch 1928/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1426 - accuracy: 0.9280
#
# Epoch 01928: loss did not improve from 0.14269
# Epoch 1929/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1421 - accuracy: 0.9290
#
# Epoch 01929: loss did not improve from 0.14269
# Epoch 1930/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1416 - accuracy: 0.9300 0s - loss: 0.1416 - accuracy: 0.93
#
# Epoch 01930: loss improved from 0.14269 to 0.14162, saving model to ./Results\10LetterWordM.hdf5
# Epoch 1931/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1387 - accuracy: 0.9341
#
# Epoch 01931: loss did not improve from 0.14162
# Epoch 1932/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1327 - accuracy: 0.9329
#
# Epoch 01932: loss did not improve from 0.14162
# Epoch 1933/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1491 - accuracy: 0.9252
#
# Epoch 01933: loss did not improve from 0.14162
# Epoch 1934/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1356 - accuracy: 0.9332
#
# Epoch 01934: loss improved from 0.14162 to 0.14064, saving model to ./Results\10LetterWordM.hdf5
# Epoch 1935/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1343 - accuracy: 0.9285
#
# Epoch 01935: loss did not improve from 0.14064
# Epoch 1936/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1447 - accuracy: 0.9255
#
# Epoch 01936: loss did not improve from 0.14064
# Epoch 1937/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1297 - accuracy: 0.9341
#
# Epoch 01937: loss did not improve from 0.14064
# Epoch 1938/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1362 - accuracy: 0.9320
#
# Epoch 01938: loss did not improve from 0.14064
# Epoch 1939/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1431 - accuracy: 0.9254
#
# Epoch 01939: loss did not improve from 0.14064
# Epoch 1940/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1382 - accuracy: 0.9308
#
# Epoch 01940: loss improved from 0.14064 to 0.14018, saving model to ./Results\10LetterWordM.hdf5
# Epoch 1941/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 0.1366 - accuracy: 0.9335
#
# Epoch 01941: loss did not improve from 0.14018
# Epoch 1942/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1379 - accuracy: 0.9271
#
# Epoch 01942: loss did not improve from 0.14018
# Epoch 1943/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1401 - accuracy: 0.9292
#
# Epoch 01943: loss did not improve from 0.14018
# Epoch 1944/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1409 - accuracy: 0.9309
#
# Epoch 01944: loss did not improve from 0.14018
# Epoch 1945/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1344 - accuracy: 0.9315
#
# Epoch 01945: loss did not improve from 0.14018
# Epoch 1946/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1457 - accuracy: 0.9245
#
# Epoch 01946: loss did not improve from 0.14018
# Epoch 1947/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1388 - accuracy: 0.9265
#
# Epoch 01947: loss did not improve from 0.14018
# Epoch 1948/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1346 - accuracy: 0.9326
#
# Epoch 01948: loss did not improve from 0.14018
# Epoch 1949/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1422 - accuracy: 0.9287
#
# Epoch 01949: loss did not improve from 0.14018
# Epoch 1950/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1311 - accuracy: 0.9326
#
# Epoch 01950: loss improved from 0.14018 to 0.13962, saving model to ./Results\10LetterWordM.hdf5
# Epoch 1951/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1392 - accuracy: 0.9307
#
# Epoch 01951: loss did not improve from 0.13962
# Epoch 1952/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1481 - accuracy: 0.9241
#
# Epoch 01952: loss did not improve from 0.13962
# Epoch 1953/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1343 - accuracy: 0.9339
#
# Epoch 01953: loss did not improve from 0.13962
# Epoch 1954/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1417 - accuracy: 0.9258
#
# Epoch 01954: loss did not improve from 0.13962
# Epoch 1955/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1361 - accuracy: 0.9306
#
# Epoch 01955: loss did not improve from 0.13962
# Epoch 1956/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1361 - accuracy: 0.9340
#
# Epoch 01956: loss did not improve from 0.13962
# Epoch 1957/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1398 - accuracy: 0.9291
#
# Epoch 01957: loss did not improve from 0.13962
# Epoch 1958/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1363 - accuracy: 0.9308
#
# Epoch 01958: loss did not improve from 0.13962
# Epoch 1959/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1489 - accuracy: 0.9264
#
# Epoch 01959: loss did not improve from 0.13962
# Epoch 1960/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1577 - accuracy: 0.9255
#
# Epoch 01960: loss did not improve from 0.13962
# Epoch 1961/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1482 - accuracy: 0.9273
#
# Epoch 01961: loss did not improve from 0.13962
# Epoch 1962/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1540 - accuracy: 0.9251
#
# Epoch 01962: loss did not improve from 0.13962
# Epoch 1963/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1465 - accuracy: 0.9275
#
# Epoch 01963: loss did not improve from 0.13962
# Epoch 1964/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1434 - accuracy: 0.9300
#
# Epoch 01964: loss did not improve from 0.13962
# Epoch 1965/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1428 - accuracy: 0.9316
#
# Epoch 01965: loss did not improve from 0.13962
# Epoch 1966/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1407 - accuracy: 0.9276
#
# Epoch 01966: loss did not improve from 0.13962
# Epoch 1967/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1407 - accuracy: 0.9320
#
# Epoch 01967: loss did not improve from 0.13962
# Epoch 1968/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1389 - accuracy: 0.9286
#
# Epoch 01968: loss did not improve from 0.13962
# Epoch 1969/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1362 - accuracy: 0.9338
#
# Epoch 01969: loss did not improve from 0.13962
# Epoch 1970/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1427 - accuracy: 0.9308
#
# Epoch 01970: loss did not improve from 0.13962
# Epoch 1971/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1441 - accuracy: 0.9318
#
# Epoch 01971: loss did not improve from 0.13962
# Epoch 1972/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1520 - accuracy: 0.9254
#
# Epoch 01972: loss did not improve from 0.13962
# Epoch 1973/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1467 - accuracy: 0.9290
#
# Epoch 01973: loss did not improve from 0.13962
# Epoch 1974/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1408 - accuracy: 0.9305
#
# Epoch 01974: loss did not improve from 0.13962
# Epoch 1975/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.1409 - accuracy: 0.9296
#
# Epoch 01975: loss did not improve from 0.13962
# Epoch 1976/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1349 - accuracy: 0.9333
#
# Epoch 01976: loss did not improve from 0.13962
# Epoch 1977/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1346 - accuracy: 0.9317
#
# Epoch 01977: loss did not improve from 0.13962
# Epoch 1978/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1491 - accuracy: 0.9290
#
# Epoch 01978: loss did not improve from 0.13962
# Epoch 1979/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1586 - accuracy: 0.9258
#
# Epoch 01979: loss did not improve from 0.13962
# Epoch 1980/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1798 - accuracy: 0.9195
#
# Epoch 01980: loss did not improve from 0.13962
# Epoch 1981/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1667 - accuracy: 0.9232
#
# Epoch 01981: loss did not improve from 0.13962
# Epoch 1982/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1512 - accuracy: 0.9292
#
# Epoch 01982: loss did not improve from 0.13962
# Epoch 1983/2000
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1597 - accuracy: 0.9292
#
# Epoch 01983: loss did not improve from 0.13962
# Epoch 1984/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1581 - accuracy: 0.9265
#
# Epoch 01984: loss did not improve from 0.13962
# Epoch 1985/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1468 - accuracy: 0.9319
#
# Epoch 01985: loss did not improve from 0.13962
# Epoch 1986/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1580 - accuracy: 0.9249
#
# Epoch 01986: loss did not improve from 0.13962
# Epoch 1987/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1589 - accuracy: 0.9245
#
# Epoch 01987: loss did not improve from 0.13962
# Epoch 1988/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1608 - accuracy: 0.9247
#
# Epoch 01988: loss did not improve from 0.13962
# Epoch 1989/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1638 - accuracy: 0.9252
#
# Epoch 01989: loss did not improve from 0.13962
# Epoch 1990/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1625 - accuracy: 0.9185
#
# Epoch 01990: loss did not improve from 0.13962
# Epoch 1991/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1646 - accuracy: 0.9200
#
# Epoch 01991: loss did not improve from 0.13962
# Epoch 1992/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1645 - accuracy: 0.9253
#
# Epoch 01992: loss did not improve from 0.13962
# Epoch 1993/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1905 - accuracy: 0.9165
#
# Epoch 01993: loss did not improve from 0.13962
# Epoch 1994/2000
# 26/26 [==============================] - 1s 19ms/step - loss: 0.2254 - accuracy: 0.9137
#
# Epoch 01994: loss did not improve from 0.13962
# Epoch 1995/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.3538 - accuracy: 0.8799
#
# Epoch 01995: loss did not improve from 0.13962
# Epoch 1996/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2629 - accuracy: 0.9023
#
# Epoch 01996: loss did not improve from 0.13962
# Epoch 1997/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2852 - accuracy: 0.8872
#
# Epoch 01997: loss did not improve from 0.13962
# Epoch 1998/2000
# 26/26 [==============================] - 1s 21ms/step - loss: 0.3038 - accuracy: 0.8915
#
# Epoch 01998: loss did not improve from 0.13962
# Epoch 1999/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.2477 - accuracy: 0.9073
#
# Epoch 01999: loss did not improve from 0.13962
# Epoch 2000/2000
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1833 - accuracy: 0.9239
#
# Epoch 02000: loss did not improve from 0.13962

# %% [markdown]
# ### Model weight load and evaluate it

# %%
WordsM = WordsModel()
WordsM.compile(loss=tf.losses.categorical_crossentropy, optimizer='adam', metrics =['accuracy'])
print('Before loading weights')
print(WordsM.evaluate(InpData, TargetData, batch_size=300 ))
print()

WordsM.load_weights(ModelSaveSameName)
print('After loading weights')
print(WordsM.evaluate(InpData, TargetData, batch_size=300))
# Out:
# Before loading weights
# 9/9 [==============================] - 2s 15ms/step - loss: 3.2574 - accuracy: 0.0304
# [3.2575080394744873, 0.027669524773955345]
#
# After loading weights
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1314 - accuracy: 0.9362
# [0.13139788806438446, 0.936217188835144]

# %% [markdown]
# ### Plot loss graphs

# %%
plt.plot(WordsMHist.history['loss'], label='Tr', marker='.')
plt.legend() 
plt.xlabel('epoch')
plt.ylabel('loss')

# %%
Dataset.head()

# %% [markdown]
# ### Prediction example

# %%
AlphaInp = input().upper()
AlphaInpEncod = [AlphOneHot.values[char_to_int[i]][None] for i in AlphaInp ]
AlphaInpEncod = np.concatenate(AlphaInpEncod, axis=0)
AlphaPred = WordsM.predict(AlphaInpEncod[None])

plt.figure(figsize=(18,4))    
sns.heatmap(AlphaPred[0], xticklabels=[i for i in char_to_int], annot=np.round(AlphaPred[0], 2),linewidths=0)
