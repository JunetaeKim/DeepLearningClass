# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# #### Given data

# %%
Pred = np.arange(0.02, 1, 0.02)
NegLogPredP = -np.log(Pred)
NegLogPredQ = -np.log(1- Pred)

# %% [markdown]
# ### If y==1

# %%
plt.figure(figsize=(6, 6))
plt.plot(Pred, NegLogPredP)

# %% [markdown]
# ### If y==0

# %%
plt.figure(figsize=(6, 6))
plt.plot(Pred, NegLogPredQ, c='red')

# %%
plt.figure(figsize=(7, 6))
plt.plot(Pred, NegLogPredP, c='blue')
plt.plot(Pred, NegLogPredQ, c='red')
