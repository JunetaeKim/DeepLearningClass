# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# #### Given data

# %%
x1 = np.array([2,4,6,8])
x2 = np.array([0,4,2,3])
y = np.array([81,93,91,97])

# %% [markdown]
# ### Visualization of 3d data

# %%
plt.figure(figsize=(6,6))
ax = plt.axes(projection='3d')
ax.set_xlabel('Study hours')
ax.set_ylabel('Private tutoring')
ax.set_zlabel('Score')
ax.scatter(x1,x2,y, s=50)

# %% [markdown]
# #### Hyperparameter setting

# %%
lr = 0.05
epochs = 2001

# %% [markdown]
# #### Complete the code below to generate a function for derivatives

# %%
def DoDiffernce ():
    
    y_pred =
    error = 
    RMSE =  
    
    # Derivatives
    a1_diff =
    a2_diff =
    b_diff = 
    
    return a1_diff, a2_diff, b_diff, RMSE

# %% [markdown]
# ### Initialization of a and b

# %%
a1 = 0
a2 = 0 
b = 0

# %% [markdown]
# ### Complete the code below to generate a loop for gradient descent

# %%
List_a1 = []
List_a2 = []
List_b = []
List_RMSE = []

for i in range(epochs):
    
    # Calculating derivative
     = DoDiffernce() 
    
    # Updating a and b
    a1 = 
    a2 = 
    b = 
    
    List_a1.append(a1)
    List_a2.append(a2)
    List_b.append(b)
    List_RMSE.append(RMSE)

# %% [markdown]
# #### Write the code to check the association between erros and a1

# %% [markdown]
# #### Write the code to check the association between erros and a2

# %% [markdown]
# #### Write the code to check the association between erros and b

# %%
## 1d prediction
y_pred = a1 * x1 + a2 * x2 + b

## 2d prediction for visualizing 2d plane
x1_2d, x2_2d = np.meshgrid(np.linspace(x1.min(),x1.max(),4), np.linspace(x2.min(),x2.max(),4))
y_pred_2d = a1 * x1_2d + a2 * x2_2d + b

# %%
plt.figure(figsize=(6,6))
ax = plt.axes(projection='3d')
ax.set_xlabel('Study hours')
ax.set_ylabel('Private tutoring')
ax.set_zlabel('Score')
ax.scatter(x1,x2,y, s= 50, label='True')
ax.scatter(x1,x2,y_pred, s= 50, label='Predicted')
ax.plot_surface(x1_2d, x2_2d, y_pred_2d, alpha=0.2)

plt.legend()
